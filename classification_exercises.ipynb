# %% [markdown]
# # Exercises
#
# Within your codeup-data-science directory, create a new directory named classification-exercises. This will be where you do your work for this module. Create a repository on GitHub with the same name, and link your local repository to GitHub. Make sure to add a .gitignore file. In your .gitignore, ignore .DS_Store, .ipynb_checkpoints/, __pycache__, titanic.csv, iris.csv, and env.py. Add and commit your .gitignore file before moving forward.
#
# The end product of this exercise is a jupyter notebook (classification_exercises.ipynb) and acquire.py. The notebook will contain all your work as you move through the exercises. The acquire.py file should contain the final functions.
#
# #### 1. In a jupyter notebook, classification_exercises.ipynb, use a python module (pydata or seaborn datasets) containing datasets as a source from the iris data. Create a pandas dataframe, df_iris, from this data.
#
#  - print the first 3 rows
#  - print the number of rows and columns (shape)
#  - print the column names
#  - print the data type of each column
#  - print the summary statistics for each of the numeric variables. Would you recommend rescaling the data based on   these statistics?

# %%
import numpy as np
import seaborn as sns
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
from pydataset import data
from env import username, password, host
import os

# %%
# df_iris = pd.DataFrame("iris")
df_iris = data("iris")
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
df_iris.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %%
df_iris.shape
# Out:
# (150, 5)

# %%
df_iris.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
df_iris.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# Sepal.Length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# Sepal.Width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# Petal.Length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# Petal.Width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %% [markdown]
# ##### Response
# Based on the df_iris dataset statistics, I would not recommend rescaling the data.

# %% [markdown]
# #### 2. Read the Table1_CustDetails table from the Excel_Exercises.xlsx file into a dataframe named df_excel.
#
#  - assign the first 100 rows to a new dataframe, df_excel_sample
#  - print the number of rows of your original dataframe
#  - print the first 5 column names
#  - print the column names that have a data type of object
#  - compute the range for each of the numeric variables.

# %%
excel_exercises = pd.read_excel('Excel_Exercises.xlsx')
excel_exercises
# Out:
#        Unnamed: 0 Unnamed: 1         Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0     customer_id     gender  is_senior_citizen    partner  dependents
# 1      1371-DWPAZ     Female                  0        Yes         Yes
# 2      2520-SGTTA     Female                  0        Yes         Yes
# 3      2775-SEFEE       Male                  0         No         Yes
# 4      2923-ARZLG       Male                  0        Yes         Yes
# ...           ...        ...                ...        ...         ...
# 7039   9987-LUTYD     Female                  0         No          No
# 7040   9992-RRAMN       Male                  0        Yes          No
# 7041   9992-UJOEL       Male                  0         No          No
# 7042   9993-LHIEB       Male                  0        Yes         Yes
# 7043   9995-HOTOH       Male                  0        Yes         Yes
#
#          Unnamed: 5        Unnamed: 6     Unnamed: 7  \
# 0     phone_service  internet_service  contract_type
# ...

# %%
df_excel_sample = excel_exercises.head(100)
df_excel_sample
# Out:
#      Unnamed: 0 Unnamed: 1         Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0   customer_id     gender  is_senior_citizen    partner  dependents
# 1    1371-DWPAZ     Female                  0        Yes         Yes
# 2    2520-SGTTA     Female                  0        Yes         Yes
# 3    2775-SEFEE       Male                  0         No         Yes
# 4    2923-ARZLG       Male                  0        Yes         Yes
# 5    3115-CZMZD       Male                  0         No         Yes
# 6    3213-VVOLG       Male                  0        Yes         Yes
# 7    4075-WKNIU     Female                  0        Yes         Yes
# 8    4367-NUYAO       Male                  0        Yes         Yes
# 9    4472-LVYGI     Female                  0        Yes         Yes
# 10   5709-LVOEQ     Female                  0        Yes         Yes
# 11   7644-OMVMY       Male                  0        Yes         Yes
# 12   0002-ORFBO     Female                  0        Yes         Yes
# ...

# %%
print(df_excel_sample.index)
print(df_excel_sample.shape[0])
# Out:
# RangeIndex(start=0, stop=100, step=1)
# 100

# %%
df_excel_sample.columns[:5]
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='object')

# %%
df_excel_sample.dtypes.index
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Excel overview-> Exercise2',
#        'Excel functions -> Exercise1', 'Excel functions -> Exercise1.1',
#        'Excel functions -> Exercise1.2', 'Excel functions -> Exercise1.3',
#        'Excel functions -> Exercise1.4', 'Excel functions -> Exercise2',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Excel functions -> Exercise3',
#        'Excel functions -> Exercise4', 'Excel functions -> Exercise4.1',
#        'Excel functions -> Exercise5', 'Excel functions -> Exercise5.1',
#        'Excel functions -> Exercise5.2'],
#       dtype='object')

# %% [markdown]
# #### 3. Read the data from this google sheet into a dataframe, df_google
#
#  - print the first 3 rows
#  - print the number of rows and columns
#  - print the column names
#  - print the data type of each column
#  - print the summary statistics for each of the numeric variables
#  - print the unique values for each of your categorical variables

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit?usp=sharing'
csv_export_url = sheet_url.replace('/edit?usp=sharing', '/export?format=csv&gid=341089357')
df_google = pd.read_csv(csv_export_url)
df_google
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                                 Heikkinen, Miss. Laina  female  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                               Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df_google.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df_google.shape
# Out:
# (891, 12)

# %%
df_google.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_google.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df_google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_google.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df_google.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# #### Make a new python module, acquire.py to hold the following data aquisition functions:
#
# 1. Make a function named get_titanic_data that returns the titanic data from the codeup data science database as a pandas data frame. Obtain your data from the Codeup Data Science Database.
#
# 2. Make a function named get_iris_data that returns the data from the iris_db on the codeup data science database as a pandas data frame. The returned data frame should include the actual name of the species in addition to the species_ids. Obtain your data from the Codeup Data Science Database.
#
# 3. Once you've got your get_titanic_data and get_iris_data functions written, now it's time to add caching to them. To do this, edit the beginning of the function to check for a local filename like titanic.csv or iris.csv. If they exist, use the .csv file. If the file doesn't exist, then produce the SQL and pandas necessary to create a dataframe, then write the dataframe to a .csv file with the appropriate name.
#
# #### Be sure to add titanic.csv and iris.csv to your .gitignore file

# %%
sql_query = 'SELECT * FROM passengers'

# %%
connection_url = f'mysql+pymysql://{username}:{password}@{host}/titanic_db'

# %%
titanic_df = pd.read_sql(sql_query, connection_url)
titanic_df.head(3)
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
#
#   embarked  class  deck  embark_town  alone
# 0        S  Third  None  Southampton      0
# 1        C  First     C    Cherbourg      0
# 2        S  Third  None  Southampton      1

# %%
titanic_df.shape
# Out:
# (891, 13)

# %%
from acquire import get_connection, new_titanic_data

# %%
titanic_df = new_titanic_data()
titanic_df.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class  deck  embark_town  alone
# 0        S  Third  None  Southampton      0
# 1        C  First     C    Cherbourg      0
# 2        S  Third  None  Southampton      1
# 3        S  First     C  Southampton      0
# 4        S  Third  None  Southampton      1

# %%
os.path.isfile('titanic_df.csv')
# Out:
# True

# %%
titanic_df.to_csv('titanic_df.csv')

# %%
os.path.isfile('titanic_df.csv')
# Out:
# True

# %%
from acquire import get_iris_data

# %%
iris_df = get_iris_data()
iris_df.head()
# Out:
#    species_id species_name  measurement_id  sepal_length  sepal_width  \
# 0           1       setosa               1           5.1          3.5
# 1           1       setosa               2           4.9          3.0
# 2           1       setosa               3           4.7          3.2
# 3           1       setosa               4           4.6          3.1
# 4           1       setosa               5           5.0          3.6
#
#    petal_length  petal_width
# 0           1.4          0.2
# 1           1.4          0.2
# 2           1.3          0.2
# 3           1.5          0.2
# 4           1.4          0.2

# %%
iris_df
# Out:
#      species_id species_name  measurement_id  sepal_length  sepal_width  \
# 0             1       setosa               1           5.1          3.5
# 1             1       setosa               2           4.9          3.0
# 2             1       setosa               3           4.7          3.2
# 3             1       setosa               4           4.6          3.1
# 4             1       setosa               5           5.0          3.6
# 5             1       setosa               6           5.4          3.9
# 6             1       setosa               7           4.6          3.4
# 7             1       setosa               8           5.0          3.4
# 8             1       setosa               9           4.4          2.9
# 9             1       setosa              10           4.9          3.1
# 10            1       setosa              11           5.4          3.7
# 11            1       setosa              12           4.8          3.4
# ...

# %%
iris_df.to_csv('iris_df.csv')

# %%
os.path.isfile('iris_df.csv')
# Out:
# True

# %%
iris_df = get_iris_data()
# iris_df.head()

# %%
iris_df = iris_df.drop(columns = ["species_id", "measurement_id"])

# %%
iris_df = iris_df.rename(columns = {"species_name" : "species"})

# %%
iris_df
# Out:
#         species  sepal_length  sepal_width  petal_length  petal_width
# 0        setosa           5.1          3.5           1.4          0.2
# 1        setosa           4.9          3.0           1.4          0.2
# 2        setosa           4.7          3.2           1.3          0.2
# 3        setosa           4.6          3.1           1.5          0.2
# 4        setosa           5.0          3.6           1.4          0.2
# 5        setosa           5.4          3.9           1.7          0.4
# 6        setosa           4.6          3.4           1.4          0.3
# 7        setosa           5.0          3.4           1.5          0.2
# 8        setosa           4.4          2.9           1.4          0.2
# 9        setosa           4.9          3.1           1.5          0.1
# 10       setosa           5.4          3.7           1.5          0.2
# 11       setosa           4.8          3.4           1.6          0.2
# ...

# %%
species_dummy = pd.get_dummies(iris_df[["species"]])
species_dummy
# Out:
#      species_setosa  species_versicolor  species_virginica
# 0                 1                   0                  0
# 1                 1                   0                  0
# 2                 1                   0                  0
# 3                 1                   0                  0
# 4                 1                   0                  0
# 5                 1                   0                  0
# 6                 1                   0                  0
# 7                 1                   0                  0
# 8                 1                   0                  0
# 9                 1                   0                  0
# 10                1                   0                  0
# 11                1                   0                  0
# 12                1                   0                  0
# 13                1                   0                  0
# 14                1                   0                  0
# ...

# %%
iris_df = pd.concat([iris_df, species_dummy], axis = 1)
iris_df
# Out:
#         species  sepal_length  sepal_width  petal_length  petal_width  \
# 0        setosa           5.1          3.5           1.4          0.2
# 1        setosa           4.9          3.0           1.4          0.2
# 2        setosa           4.7          3.2           1.3          0.2
# 3        setosa           4.6          3.1           1.5          0.2
# 4        setosa           5.0          3.6           1.4          0.2
# 5        setosa           5.4          3.9           1.7          0.4
# 6        setosa           4.6          3.4           1.4          0.3
# 7        setosa           5.0          3.4           1.5          0.2
# 8        setosa           4.4          2.9           1.4          0.2
# 9        setosa           4.9          3.1           1.5          0.1
# 10       setosa           5.4          3.7           1.5          0.2
# 11       setosa           4.8          3.4           1.6          0.2
# ...

# %% [markdown]
# ### Exploratory Analysis Exercises
#
# Continue in your classification_exercises.ipynb notebook. As always, add, commit, and push your changes.
#
# ##### Section 1 - iris_db: Using iris data from our mySQL server and the methods used in the lesson above:
#
# 1. Acquire, prepare & split your data.
#
# 2. Univariate Stats
#
# - For each measurement type (quantitative variable): create a histogram, boxplot, & compute descriptive statistics (using .describe()).
#
# - For each species (categorical variable): create a frequency table and a bar plot of those frequencies.
#
# - Document takeaways & any actions.

# %%
iris_df
# Out:
#         species  sepal_length  sepal_width  petal_length  petal_width  \
# 0        setosa           5.1          3.5           1.4          0.2
# 1        setosa           4.9          3.0           1.4          0.2
# 2        setosa           4.7          3.2           1.3          0.2
# 3        setosa           4.6          3.1           1.5          0.2
# 4        setosa           5.0          3.6           1.4          0.2
# 5        setosa           5.4          3.9           1.7          0.4
# 6        setosa           4.6          3.4           1.4          0.3
# 7        setosa           5.0          3.4           1.5          0.2
# 8        setosa           4.4          2.9           1.4          0.2
# 9        setosa           4.9          3.1           1.5          0.1
# 10       setosa           5.4          3.7           1.5          0.2
# 11       setosa           4.8          3.4           1.6          0.2
# ...

# %%
plt.figure(figsize = (12, 10))
plt.suptitle('Continuous Iris Db Variables')

plt.subplot(221)
sns.histplot(data = iris_df, x = 'sepal_length', hue = "species")
plt.title('Sepal Length')

plt.subplot(222)
sns.histplot(data = iris_df, x = 'sepal_width', hue = 'species')
plt.title('Sepal Width')

plt.subplot(223)
sns.histplot(data = iris_df, x = 'petal_length', hue = "species")
plt.title('Petal Length')

plt.subplot(224)
sns.histplot(data = iris_df, x = 'petal_width', hue = "species")
plt.title('Petal Width')

plt.subplots_adjust(hspace = 0.4)

# %%
plt.figure(figsize = (12, 10))
plt.suptitle('Continuous Iris Db Variables')

plt.subplot(221)
sns.boxplot(data = iris_df, x = 'sepal_length', y = "species")
plt.title('Sepal Length')

plt.subplot(222)
sns.boxplot(data = iris_df, x = 'sepal_width', y = "species")
plt.title('Sepal Width')

plt.subplot(223)
sns.boxplot(data = iris_df, x = 'petal_length', y = "species")
plt.title('Petal Length')

plt.subplot(224)
sns.boxplot(data = iris_df, x = 'petal_width', y = "species")
plt.title('Petal Width')

plt.subplots_adjust(hspace = 0.4)

# %%
iris_df.describe().T
# Out:
#                     count      mean       std  min  25%   50%  75%  max
# sepal_length        150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width         150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# petal_length        150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# petal_width         150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5
# species_setosa      150.0  0.333333  0.472984  0.0  0.0  0.00  1.0  1.0
# species_versicolor  150.0  0.333333  0.472984  0.0  0.0  0.00  1.0  1.0
# species_virginica   150.0  0.333333  0.472984  0.0  0.0  0.00  1.0  1.0

# %% [markdown]
# - For each species (categorical variable): create a frequency table and a bar plot of those frequencies

# %%
plt.figure(figsize = (12, 10))
plt.suptitle('Categorical Iris Db Variables: Species')

plt.subplot(221)
sns.barplot(data = iris_df, x = 'species', y = "sepal_length")
plt.title('Sepal length')

plt.subplot(222)
sns.barplot(data = iris_df, x = 'species', y = "sepal_width")
plt.title('Sepal Width')

plt.subplot(223)
sns.barplot(data = iris_df, x = 'species', y = "petal_length")
plt.title('Petal Length')

plt.subplot(224)
sns.barplot(data = iris_df, x = 'species', y = "petal_width")
plt.title('Petal Width')

plt.subplots_adjust(hspace = 0.4)

# %%
# x = (iris_df.groupby(by = "species").count())
# y = iris_df["sepal_length"]

# plt.barplot(x, y)

# %%
from sklearn.model_selection import train_test_split

# %%
# 80/20 train/test split
train, test = train_test_split(iris_df, train_size = 0.8, random_state = 1349, stratify = iris_df.species)

# 70/30 train/validate split

train, validate = train_test_split(train, train_size = 0.7, random_state = 1349, stratify = train.species)

# %%
train.shape, validate.shape, test.shape
# Out:
# ((84, 8), (36, 8), (30, 8))

# %% [markdown]
# EXERCISE 2

# %%
melted = train.melt(id_vars = ["species"])

# %%
melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588 entries, 0 to 587
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   species   588 non-null    object
#  1   variable  588 non-null    object
#  2   value     588 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 13.9+ KB

# %%
melted.head()
# Out:
#       species      variable  value
# 0   virginica  sepal_length    6.0
# 1      setosa  sepal_length    5.0
# 2  versicolor  sepal_length    5.7
# 3  versicolor  sepal_length    6.4
# 4  versicolor  sepal_length    6.2

# %%
train.shape
# Out:
# (84, 8)

# %%
plt.rc("font", size = 14)
plt.rc("figure", figsize = (14, 10))

# %%
sns.swarmplot(data = melted, x = "variable", y = "value", hue = "species")
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 59.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='variable', ylabel='value'>

# %% [markdown]
# EXERCISE 3

# %%
train["sepal_area"] = train.sepal_length * train.sepal_width
train["petal_area"] = train["petal_length"] * train["petal_width"]

# %%
train.head()
# Out:
#         species  sepal_length  sepal_width  petal_length  petal_width  \
# 138   virginica           6.0          3.0           4.8          1.8
# 7        setosa           5.0          3.4           1.5          0.2
# 79   versicolor           5.7          2.6           3.5          1.0
# 74   versicolor           6.4          2.9           4.3          1.3
# 97   versicolor           6.2          2.9           4.3          1.3
#
#      species_setosa  species_versicolor  species_virginica  sepal_area  \
# 138               0                   0                  1       18.00
# 7                 1                   0                  0       17.00
# 79                0                   1                  0       14.82
# 74                0                   1                  0       18.56
# 97                0                   1                  0       17.98
#
#      petal_area
# 138        8.64
# 7          0.30
# 79         3.50
# 74         5.59
# 97         5.59

# %%
combos = [
    ("sepal_length", "sepal_width"),
    ("petal_length", "petal_width"),
    ("sepal_area", "petal_area"),
    ("sepal_length", "petal_length")
]

# %%
combos[0]
# Out:
# ('sepal_length', 'sepal_width')

# %%
train.groupby("species")["sepal_area"].sum()
# Out:
# species
# setosa        473.12
# versicolor    467.81
# virginica     554.13
# Name: sepal_area, dtype: float64

# %%
for species, subset in train.groupby("species"):
    print(subset.head())
    print(type(species))
# Out:
#    species  sepal_length  sepal_width  petal_length  petal_width  \
# 7   setosa           5.0          3.4           1.5          0.2
# 13  setosa           4.3          3.0           1.1          0.1
# 42  setosa           4.4          3.2           1.3          0.2
# 16  setosa           5.4          3.9           1.3          0.4
# 25  setosa           5.0          3.0           1.6          0.2
#
#     species_setosa  species_versicolor  species_virginica  sepal_area  \
# 7                1                   0                  0       17.00
# 13               1                   0                  0       12.90
# 42               1                   0                  0       14.08
# 16               1                   0                  0       21.06
# 25               1                   0                  0       15.00
#
#     petal_area
# 7         0.30
# 13        0.11
# 42        0.26
# 16        0.52
# 25        0.32
# <class 'str'>
# ...

# %%
x = combos[0][0]
y = combos[0][1]
def scatter_species(x, y):
    for species, subset in train.groupby("species"):
        plt.scatter(subset[x], subset[y])
        plt.xlabel(x)
        plt.ylabel(y)
        plt.legend()
        #plt.show()

# %%
# test it with one plot
scatter_species(x, y)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
plt.subplot(2,2,1)
scatter_species(combos[0][0], combos[0][1])
plt.subplot(2,2,2)
scatter_species(combos[1][0], combos[1][1])
plt.subplot(2,2,3)
scatter_species(combos[2][0], combos[2][1])
plt.subplot(2,2,4)
scatter_species(combos[3][0], combos[3][1])
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
for i, pair in enumerate(combos):
    plt.subplot(2,2, i+1)
    scatter_species(pair[0], pair[1])
#     print(i)
#     print(pair)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# EXERCISE 4

# %%
train.corr()
# Out:
#                     sepal_length  sepal_width  petal_length  petal_width  \
# sepal_length            1.000000    -0.166612      0.900357     0.860775
# sepal_width            -0.166612     1.000000     -0.415310    -0.323396
# petal_length            0.900357    -0.415310      1.000000     0.965383
# petal_width             0.860775    -0.323396      0.965383     1.000000
# species_setosa         -0.752913     0.566281     -0.919061    -0.882093
# species_versicolor      0.074486    -0.432322      0.193310     0.113537
# species_virginica       0.678427    -0.133959      0.725751     0.768556
# sepal_area              0.685879     0.599240      0.429428     0.473277
# petal_area              0.885277    -0.272634      0.958520     0.980366
#
#                     species_setosa  species_versicolor  species_virginica  \
# sepal_length             -0.752913            0.074486           0.678427
# sepal_width               0.566281           -0.432322          -0.133959
# ...

# %%
sns.heatmap(train.corr(), cmap = "mako", center = 0, annot = True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# EXEERCISE 6

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84 entries, 138 to 54
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   species             84 non-null     object
#  1   sepal_length        84 non-null     float64
#  2   sepal_width         84 non-null     float64
#  3   petal_length        84 non-null     float64
#  4   petal_width         84 non-null     float64
#  5   species_setosa      84 non-null     uint8
#  6   species_versicolor  84 non-null     uint8
#  7   species_virginica   84 non-null     uint8
#  8   sepal_area          84 non-null     float64
#  9   petal_area          84 non-null     float64
# dtypes: float64(6), object(1), uint8(3)
# memory usage: 5.5+ KB

# %% [markdown]
# iS THE SEPAL LENGTH SIGNIFICANTLY DIFFERENT IN VIRGINICA COMPARED TO VERSICOLOR?

# %% [markdown]
# Hypothesis
# alpha = 0.05
# H0: Sepal length is the same in virginica and versicolor.
# Ha: Sepal length is significanlty different in virginica and vesicolor.

# %%
virginica = train[train["species"] == "virginica"]
versicolor = train[train["species"] == "versicolor"]

# %%
virginica.hist()
plt.show()

# %%
versicolor.hist()
plt.show()

# %%
virginica.describe()["sepal_length"]["std"] ** 2
# Out:
# 0.2840740740740741

# %%
versicolor.describe()["sepal_length"]
# Out:
# count    28.000000
# mean      5.935714
# std       0.512231
# min       5.000000
# 25%       5.600000
# 50%       6.000000
# 75%       6.300000
# max       6.900000
# Name: sepal_length, dtype: float64

# %%
import scipy.stats as stats

# %%
tstat, p = stats.ttest_ind(virginica.sepal_length,
               versicolor.sepal_length,
               equal_var = False
               )

# %%
tstat
# Out:
# 5.11297615624047

# %%
p
# Out:
# 4.304267066877367e-06

# %%
sns.catplot(data = train, x = "species", y = "petal_area")

# %%
sns.relplot(data = train, x = "sepal_area", y = "petal_area", kind = "scatter", hue = "species", col = "species")
